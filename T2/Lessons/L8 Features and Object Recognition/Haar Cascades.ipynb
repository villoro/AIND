# %% [markdown]
# # Haar Cascades

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
image = cv2.cvtColor(cv2.imread('face1.jpg'), cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap="gray")

# %%
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-17-bf0cc6a34bc8> in <module>()
#       1 face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
#       2
# ----> 3 faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#
# error: C:\bld\opencv_1498174012660\work\opencv-3.2.0\modules\objdetect\src\cascadedetect.cpp:1681: error: (-215) !empty() in function cv::CascadeClassifier::detectMultiScale
