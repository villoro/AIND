# %% [markdown]
# # Text Processing
#
# ## Capturing Text Data
#
# ### Plain Text

# %%
import os

# Read in a plain text file
with open(os.path.join("data", "hieroglyph.txt"), "r") as f:
    text = f.read()
    print(text)
# Out:
# Hieroglyphic writing dates from c. 3000 BC, and is composed of hundreds of symbols. A hieroglyph can represent a word, a sound, or a silent determinative; and the same symbol can serve different purposes in different contexts. Hieroglyphs were a formal script, used on stone monuments and in tombs, that could be as detailed as individual works of art.

# %% [markdown]
# ### Tabular Data

# %%
import pandas as pd

# Extract text column from a dataframe
df = pd.read_csv(os.path.join("data", "news.csv"))
df.head()[['publisher', 'title']]

# Convert text column to lowercase
df['title'] = df['title'].str.lower()
df.head()[['publisher', 'title']]
# Out:
#       publisher                                              title
# 0      Livemint  fed's charles plosser sees high bar for change...
# 1  IFA Magazine  us open: stocks fall after fed official hints ...
# 2  IFA Magazine  fed risks falling 'behind the curve', charles ...
# 3     Moneynews  fed's plosser: nasty weather has curbed job gr...
# 4        NASDAQ  plosser: fed may have to accelerate tapering pace

# %% [markdown]
# ### Online Resource

# %%
import requests
import json

# Fetch data from a REST API
r = requests.get(
    "https://quotes.rest/qod.json")
res = r.json()
print(json.dumps(res, indent=4))

# Extract relevant object and field
q = res["contents"]["quotes"][0]
print(q["quote"], "\n--", q["author"])
# Out:
# {
#     "success": {
#         "total": 1
#     },
#     "contents": {
#         "quotes": [
#             {
#                 "quote": "The human mind and body are truly extraordinary. They are the quintessence of excellence in motion. We talk, touch, see, hear, taste, smell, and feel. We dream, aspire, and become. All that we are is mind and body and spirit\u2014that is our universe.",
#                 "length": "253",
#                 "author": "Lorii Myers",
#                 "tags": [
#                     "human-body",
#                     "inspire",
#                     "mind",
#                     "tso-life"
#                 ],
#                 "category": "inspire",
#                 "date": "2018-03-29",
#                 "permalink": "https://theysaidso.com/quote/dZWOGcDFcNB_jy_XhjmnDweF/lorii-myers-the-human-mind-and-body-are-truly-extraordinary-they-are-the-quintes",
#                 "title": "Inspiring Quote of the day",
#                 "background": "https://theysaidso.com/img/bgs/man_on_the_mountain.jpg",
#                 "id": "dZWOGcDFcNB_jy_XhjmnDweF"
#             }
#         ],
#         "copyright": "2017-19 theysaidso.com"
#     }
# }
# The human mind and body are truly extraordinary. They are the quintessence of excellence in motion. We talk, touch, see, hear, taste, smell, and feel. We dream, aspire, and become. All that we are is mind and body and spirit—that is our universe.
# -- Lorii Myers

# %% [markdown]
# ## Cleaning

# %%
import requests

# Fetch a web page
r = requests.get("https://www.udacity.com/courses/all")
print(r.text)
# Out:
# <!DOCTYPE html><html><head><meta charset="utf-8"><title>Catalog | Udacity</title><base href="/"><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="icon" type="image/x-icon" href="favicon.ico"><script src="assets/vendor/segment.js" async=""></script><link rel="preload" href="inline.a9ad0260c6f3e7e46672.bundle.js" as="script"><link rel="preload" href="polyfills.9bb97d0109f50b0d83b6.bundle.js" as="script"><link rel="preload" href="main.d06fff4841414abaf9bc.bundle.js" as="script"><link href="styles.4f181499f8401304f50e.bundle.css" rel="stylesheet"><style ng-transition="iridium-eu">html[_ngcontent-c0]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c0], [_ngcontent-c0]:after, [_ngcontent-c0]:before{-webkit-box-sizing:inherit;box-sizing:inherit}a[_ngcontent-c0]{color:#9400d3}body[_ngcontent-c0]{color:#028bb1}[_nghost-c0]{display:block;position:relative}</style><style ng-transition="iridium-eu">html[_ngcontent-c1]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c1], [_ngcontent-c1]:after, [_ngcontent-c1]:before{-webkit-box-sizing:inherit;box-sizing:inherit}.invisible[_ngcontent-c1]{visibility:hidden!important}.hide[_ngcontent-c1]{display:none!important}.show[_ngcontent-c1]{display:block!important}.sr-only[_ngcontent-c1]{height:1px;width:1px;overflow:hidden;position:absolute!important;clip:rect(1px,1px,1px,1px)}.hidden-xs-up[_ngcontent-c1]{display:none!important}@media (max-width:479px){.hidden-xs-down[_ngcontent-c1]{display:none!important}}@media (min-width:480px){.hidden-sm-up[_ngcontent-c1]{display:none!important}}@media (max-width:767px){.hidden-sm-down[_ngcontent-c1]{display:none!important}}@media (min-width:768px){.hidden-md-up[_ngcontent-c1]{display:none!important}}@media (max-width:991px){.hidden-md-down[_ngcontent-c1]{display:none!important}}@media (min-width:992px){.hidden-lg-up[_ngcontent-c1]{display:none!important}}@media (max-width:1179px){.hidden-lg-down[_ngcontent-c1]{display:none!important}}@media (min-width:1180px){.hidden-xl-up[_ngcontent-c1]{display:none!important}}.hidden-xl-down[_ngcontent-c1], .visible-print-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-block[_ngcontent-c1]{display:block!important}}.visible-print-inline[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline[_ngcontent-c1]{display:inline!important}}.visible-print-inline-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline-block[_ngcontent-c1]{display:inline-block!important}}@media print{.hidden-print[_ngcontent-c1]{display:none!important}}#contain-all[_ngcontent-c1]{width:100%;overflow:hidden;background:#fff;-webkit-backface-visibility:hidden;backface-visibility:hidden;-webkit-transform-style:preserve-3d}.outer_contain[_ngcontent-c1]{margin:0 auto;max-width:90rem}.contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto;padding-top:3rem;padding-bottom:3rem;padding-left:1.5rem;padding-right:1.5rem}.contain[_ngcontent-c1]:after{clear:both;content:"";display:table}@media screen and (min-width:48rem){.contain[_ngcontent-c1]{padding-top:6rem;padding-bottom:6rem}}@media screen and (min-width:73.75rem){.contain[_ngcontent-c1]{padding-left:0;padding-right:0}}.contain.no-padding[_ngcontent-c1]{padding:0}.contain.no-padding-top[_ngcontent-c1]{padding-top:0}.contain--none[_ngcontent-c1], .contain.no-padding-bottom[_ngcontent-c1]{padding-bottom:0}.contain--none[_ngcontent-c1]{padding-top:0;margin:0 auto}@media screen and (min-width:48rem){.contain--none[_ngcontent-c1]{padding-top:0;padding-bottom:0}}.contain--small[_ngcontent-c1]{padding-top:3rem;padding-bottom:3rem;margin:0 auto}@media screen and (min-width:48rem){.contain--small[_ngcontent-c1]{padding-top:4.5rem;padding-bottom:4.5rem}}.cards_contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto}.cards_contain[_ngcontent-c1]:after{clear:both;content:"";display:table}[_ngcontent-c1]:-webkit-full-screen-ancestor{-webkit-animation:none!impo ...
# Students will learn how to use header files, control flow, functions, classes.</span></div><!----></div></div><div _ngcontent-c162="" class="course-summary-card row row-gap-medium"><div _ngcontent-c162="" class="col-sm-3"><!----><img _ngcontent-c162="" class="course-thumb img-responsive img-bordered center-block" height="170" width="290" src="https://d20vrrgs8k4bvw.cloudfront.net/images/courses/thumbnails/ud595_thumbnail.jpg" alt="Linux Command Line Basics"><!----><!----></div><div _ngcontent-c162="" class="col-sm-9 course-text"><div _ngcontent-c162="" class="row"><div _ngcontent-c162="" class="col-sm-8"><h3 _ngcontent-c162="" class="h-slim"><a _ngcontent-c162="" href="/course/linux-command-line-basics--ud595"> Linux Command Line Basics</a><span _ngcontent-c162="" class="badges"><!----></span></h3></div><div _ngcontent-c162="" class="col-sm-4 hidden-xs"><!----><span _ngcontent-c162="" class="caption text-right"><span _ngcontent-c162="" data-course-level-icon="" class="icon-level course-info-bar-icon icon-level-beginner" classname="icon-level course-info-bar-icon icon-level-beginner"></span><span _ngcontent-c162="" class="capitalize" data-course-level-label="">beginner</span></span></div></div><div _ngcontent-c162=""><!----><span _ngcontent-c162="" innerhtml="An introduction to the Linux command line interface.">An introduction to the Linux command line interface.</span></div><!----></div></div><div _ngcontent-c162="" class="course-summary-card row row-gap-medium"><div _ngcontent-c162="" class="col-sm-3"><!----><img _ngcontent-c162="" class="course-thumb img-responsive img-bordered center-block" height="170" width="290" src="https://d20vrrgs8k4bvw.cloudfront.net/images/courses/thumbnails/ud359_thumbnail.jpg" alt="Intro to Data Science"><!----><!----></div><div _ngcontent-c162="" class="col-sm-9 course-text"><div _ngcontent-c162="" class="row"><div _ngcontent-c162="" class="col-sm-8"><h3 _ngcontent-c162="" class="h-slim"><a _ngcontent-c162="" href="/course/intro-to-data-science--ud359"> Intro to Data Science</a><span _ngcontent-c162="" class="badges"><!----></span></h3></div><div _ngcontent-c162="" class="col-sm-4 hidden-xs"><!----><span _ngcontent-c162="" class="caption text-right"><span _ngcontent-c162="" data-course-level-icon="" class="icon-level course-info-bar-icon icon-level-intermediate" classname="icon-level course-info-bar-icon icon-level-intermediate"></span><span _ngcontent-c162="" class="capitalize" data-course-level-label="">intermediate</span></span></div></div><div _ngcontent-c162=""><!----><span _ngcontent-c162="" innerhtml="What does a data scientist do? In this course, we will survey the main topics in data science so you can understand the skills that are needed to become a data scientist!">What does a data scientist do? In this course, we will survey the main topics in data science so you can understand the skills that are needed to become a data scientist!</span></div><!----></div></div><div _ngcontent-c162="" class="course-summary-card row row-gap-medium"><div _ngcontent-c162="" class="col-sm-3"><!----><img _ngcontent-c162="" class="course-thumb img-responsive img-bordered center-block" height="170" width="290" src="https://d20vrrgs8k4bvw.cloudfront.net/images/courses/thumbnails/ud201_thumbnail.jpg" alt="Intro to Inferential Statistics"><!----><!----></div><div _ngcontent-c162="" class="col-sm-9 course-text"><div _ngcontent-c162="" class="row"><div _ngcontent-c162="" class="col-sm-8"><h3 _ngcontent-c162="" class="h-slim"><a _ngcontent-c162="" href="/course/intro-to-inferential-statistics--ud201"> Intro to Inferential Statistics</a><span _ngcontent-c162="" class="badges"><!----></span></h3></div><div _ngcontent-c162="" class="col-sm-4 hidden-xs"><!----><span _ngcontent-c162="" class="caption text-right"><span _ngcontent-c162="" data-course-level-icon="" class="icon-level course-info-bar-icon icon-level-beginner" classname="icon-level course-info-bar-icon icon-level-beginner"></span><span _ngcontent-c162=""  ...
#
# Ideal for developers with at least 1-2 years Java experience. See prerequisites below for more detail.</span></div><!----><p _ngcontent-c162=""><span _ngcontent-c162="" class="h4">In collaboration with:</span>&nbsp;<!----><strong _ngcontent-c162="">Google </strong></p></div></div><div _ngcontent-c162="" class="course-summary-card row row-gap-medium"><div _ngcontent-c162="" class="col-sm-3"><!----><div _ngcontent-c162="" class="image-placeholder"><span _ngcontent-c162="" class="h4">No Image Available</span></div><!----><!----></div><div _ngcontent-c162="" class="col-sm-9 course-text"><div _ngcontent-c162="" class="row"><div _ngcontent-c162="" class="col-sm-8"><h3 _ngcontent-c162="" class="h-slim"><a _ngcontent-c162="" href="/course/introduction-to-health-informatics--ud835"> Introduction to Health Informatics</a><span _ngcontent-c162="" class="badges"><!----></span></h3></div><div _ngcontent-c162="" class="col-sm-4 hidden-xs"><!----></div></div><div _ngcontent-c162=""><!----><span _ngcontent-c162="" innerhtml="This survey course provides a broad, forward-facing overview of contemporary health informatics within the context of the US healthcare delivery system.">This survey course provides a broad, forward-facing overview of contemporary health informatics within the context of the US healthcare delivery system.</span></div><!----></div></div><div _ngcontent-c162="" class="course-summary-card row row-gap-medium"><div _ngcontent-c162="" class="col-sm-3"><!----><img _ngcontent-c162="" class="course-thumb img-responsive img-bordered center-block" height="170" width="290" src="https://d20vrrgs8k4bvw.cloudfront.net/images/courses/thumbnails/ud853_thumbnail.jpg" alt="Developing Android Apps"><!----><!----></div><div _ngcontent-c162="" class="col-sm-9 course-text"><div _ngcontent-c162="" class="row"><div _ngcontent-c162="" class="col-sm-8"><h3 _ngcontent-c162="" class="h-slim"><a _ngcontent-c162="" href="/course/developing-android-apps--ud853"> Developing Android Apps</a><span _ngcontent-c162="" class="badges"><!----></span></h3></div><div _ngcontent-c162="" class="col-sm-4 hidden-xs"><!----><span _ngcontent-c162="" class="caption text-right"><span _ngcontent-c162="" data-course-level-icon="" class="icon-level course-info-bar-icon icon-level-intermediate" classname="icon-level course-info-bar-icon icon-level-intermediate"></span><span _ngcontent-c162="" class="capitalize" data-course-level-label="">intermediate</span></span></div></div><div _ngcontent-c162=""><!----><span _ngcontent-c162="" innerhtml="Build a cloud-connected Android app, and learn the tools, principles, and best practices of mobile and Android development that you'll apply to your own projects.">Build a cloud-connected Android app, and learn the tools, principles, and best practices of mobile and Android development that you'll apply to your own projects.</span></div><!----><p _ngcontent-c162=""><span _ngcontent-c162="" class="h4">In collaboration with:</span>&nbsp;<!----><strong _ngcontent-c162="">Google </strong></p></div></div><div _ngcontent-c162="" class="course-summary-card row row-gap-medium"><div _ngcontent-c162="" class="col-sm-3"><!----><img _ngcontent-c162="" class="course-thumb img-responsive img-bordered center-block" height="170" width="290" src="https://d20vrrgs8k4bvw.cloudfront.net/images/courses/thumbnails/ud875B_thumbnail.jpg" alt="Android TV and Google Cast Development"><!----><!----></div><div _ngcontent-c162="" class="col-sm-9 course-text"><div _ngcontent-c162="" class="row"><div _ngcontent-c162="" class="col-sm-8"><h3 _ngcontent-c162="" class="h-slim"><a _ngcontent-c162="" href="/course/android-tv-and-google-cast-development--ud875B"> Android TV and Google Cast Development</a><span _ngcontent-c162="" class="badges"><!----></span></h3></div><div _ngcontent-c162="" class="col-sm-4 hidden-xs"><!----><span _ngcontent-c162="" class="caption text-right"><span _ngcontent-c162="" data-course-level-icon="" class="icon-level course-info-bar-icon icon-level- ...

# %%
import re

# Remove HTML tags using RegEx
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
# Catalog | Udacityhtml[_ngcontent-c0]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c0], [_ngcontent-c0]:after, [_ngcontent-c0]:before{-webkit-box-sizing:inherit;box-sizing:inherit}a[_ngcontent-c0]{color:#9400d3}body[_ngcontent-c0]{color:#028bb1}[_nghost-c0]{display:block;position:relative}html[_ngcontent-c1]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c1], [_ngcontent-c1]:after, [_ngcontent-c1]:before{-webkit-box-sizing:inherit;box-sizing:inherit}.invisible[_ngcontent-c1]{visibility:hidden!important}.hide[_ngcontent-c1]{display:none!important}.show[_ngcontent-c1]{display:block!important}.sr-only[_ngcontent-c1]{height:1px;width:1px;overflow:hidden;position:absolute!important;clip:rect(1px,1px,1px,1px)}.hidden-xs-up[_ngcontent-c1]{display:none!important}@media (max-width:479px){.hidden-xs-down[_ngcontent-c1]{display:none!important}}@media (min-width:480px){.hidden-sm-up[_ngcontent-c1]{display:none!important}}@media (max-width:767px){.hidden-sm-down[_ngcontent-c1]{display:none!important}}@media (min-width:768px){.hidden-md-up[_ngcontent-c1]{display:none!important}}@media (max-width:991px){.hidden-md-down[_ngcontent-c1]{display:none!important}}@media (min-width:992px){.hidden-lg-up[_ngcontent-c1]{display:none!important}}@media (max-width:1179px){.hidden-lg-down[_ngcontent-c1]{display:none!important}}@media (min-width:1180px){.hidden-xl-up[_ngcontent-c1]{display:none!important}}.hidden-xl-down[_ngcontent-c1], .visible-print-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-block[_ngcontent-c1]{display:block!important}}.visible-print-inline[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline[_ngcontent-c1]{display:inline!important}}.visible-print-inline-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline-block[_ngcontent-c1]{display:inline-block!important}}@media print{.hidden-print[_ngcontent-c1]{display:none!important}}#contain-all[_ngcontent-c1]{width:100%;overflow:hidden;background:#fff;-webkit-backface-visibility:hidden;backface-visibility:hidden;-webkit-transform-style:preserve-3d}.outer_contain[_ngcontent-c1]{margin:0 auto;max-width:90rem}.contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto;padding-top:3rem;padding-bottom:3rem;padding-left:1.5rem;padding-right:1.5rem}.contain[_ngcontent-c1]:after{clear:both;content:"";display:table}@media screen and (min-width:48rem){.contain[_ngcontent-c1]{padding-top:6rem;padding-bottom:6rem}}@media screen and (min-width:73.75rem){.contain[_ngcontent-c1]{padding-left:0;padding-right:0}}.contain.no-padding[_ngcontent-c1]{padding:0}.contain.no-padding-top[_ngcontent-c1]{padding-top:0}.contain--none[_ngcontent-c1], .contain.no-padding-bottom[_ngcontent-c1]{padding-bottom:0}.contain--none[_ngcontent-c1]{padding-top:0;margin:0 auto}@media screen and (min-width:48rem){.contain--none[_ngcontent-c1]{padding-top:0;padding-bottom:0}}.contain--small[_ngcontent-c1]{padding-top:3rem;padding-bottom:3rem;margin:0 auto}@media screen and (min-width:48rem){.contain--small[_ngcontent-c1]{padding-top:4.5rem;padding-bottom:4.5rem}}.cards_contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto}.cards_contain[_ngcontent-c1]:after{clear:both;content:"";display:table}[_ngcontent-c1]:-webkit-full-screen-ancestor{-webkit-animation:none!important;animation:none!important;-webkit-animation-fill-mode:none!important;animation-fill-mode:none!important}[_ngcontent-c1]:target:before{content:"";display:inline-block;height:130px;margin:-130px 0 0}.header[_ngcontent-c1]{max-width:100%;margin-left:auto;margin-right:auto}.header[_ngcontent-c1]:after{clear:both;content:"";display:table}.header.header--clone[_ngcontent-c1]{width:100%;top:-1000px}.header.header--clone[_ngcontent-c1]   .header__navbar[_ngcontent-c1]{height:4.5rem}.header.header--stick[_ngcontent-c1]{top:0;background-color:#fff;z-index:8000;-webkit-box-shadow:0 1px 2px rgba(0,0,0,.1);box-shadow:0 1px 2px rgba(0,0, ...
# Students will learn how to use header files, control flow, functions, classes. Linux Command Line BasicsbeginnerAn introduction to the Linux command line interface. Intro to Data ScienceintermediateWhat does a data scientist do? In this course, we will survey the main topics in data science so you can understand the skills that are needed to become a data scientist! Intro to Inferential StatisticsbeginnerIntro to Inferential Statistics will teach you how to test your hypotheses and begin to make predictions based on statistical results drawn from data! Machine Learning for TradingintermediateImplement machine learning based strategies to make trading decisions using real-world data.In collaboration with:&nbsp;Georgia Institute of Technology  Machine LearningintermediateIn this course, you'll learn how to apply Supervised, Unsupervised and Reinforcement Learning techniques for solving a range of data science problems.In collaboration with:&nbsp;Georgia Institute of Technology  Responsive Web Design FundamentalsintermediateLearn and practice strategies for developing websites that look great on every device! Made with Google's Pete LePage.In collaboration with:&nbsp;Google  Scalable Microservices with KubernetesNewintermediateThis course is designed to teach you about managing microservices, using Kubernetes. This course is built in partnership with experts such as Google’s Kelsey Hightower.In collaboration with:&nbsp;Google  UX Design for Mobile DevelopersbeginnerThis is a design course made for developers. You'll learn UX design skills which will help you make 5-star mobile apps that your users will love.In collaboration with:&nbsp;Google  Intro to Hadoop and MapReduceintermediateIn this short course, learn the fundamentals of MapReduce and Apache Hadoop to start making sense of Big Data in the real world!In collaboration with:&nbsp;Cloudera  Intro to Relational DatabasesintermediateRelational databases are a powerful tool used throughout the industry. Learn the basics of SQL and how to connect your Python code to a relational database. Technical InterviewNewintermediateLearn the skills technical interviewers expect you to know—efficiency, common algorithms, manipulating popular data structures, and how to explain a solution.In collaboration with:&nbsp;Pramp  Product DesignintermediateLearn product validation, UI/UX practices, Google’s Design Sprint and the process for setting and tracking actionable metrics.In collaboration with:&nbsp;Google  Swift for BeginnersNewbeginnerLearn Swift, Apple's programming language for building iOS applications. Start with the basics and work your way towards completing sets of challenges in Swift. Data Analysis with RintermediateData is everywhere and so much of it is unexplored. Learn how to investigate and summarize data sets using R and eventually create your own analysis.In collaboration with:&nbsp;Facebook  Artificial Intelligence for RoboticsadvancedLearn how to program all the major systems of a robotic car. Topics include planning, search, localization, tracking, and control.In collaboration with:&nbsp;Georgia Institute of Technology  Introduction to Computer VisionintermediateThis course provides an introduction to computer vision including fundamentals, methods for application and machine learning classification.In collaboration with:&nbsp;Georgia Institute of Technology  Front End FrameworksNewadvancedExplore and build interactive, single-page applications with popular JavaScript frameworks!In collaboration with:&nbsp;Google  Version Control with GitNewbeginnerLearn how to use Git, a popular Version Control System and essential tool for any developer. GitHub &amp; CollaborationNewbeginnerLearn how to interact with remote repositories and collaborate with other developers on GitHub. Firebase in a Weekend: AndroidNewintermediateThis course will teach you when and why to choose Firebase as a backend for your Android application.In collaboration with:&nbsp;Google  Introduction to Operat ...
#
# Ideal for developers with at least 1-2 years Java experience. See prerequisites below for more detail.In collaboration with:&nbsp;Google No Image Available Introduction to Health InformaticsThis survey course provides a broad, forward-facing overview of contemporary health informatics within the context of the US healthcare delivery system. Developing Android AppsintermediateBuild a cloud-connected Android app, and learn the tools, principles, and best practices of mobile and Android development that you'll apply to your own projects.In collaboration with:&nbsp;Google  Android TV and Google Cast DevelopmentadvancedGo where your users are: the living room! This course shows you how to extend your existing Android app to also work on Android TV, and/or with Google Cast.In collaboration with:&nbsp;Google Nanodegree ProgramsAI programming with PythonAndroid BasicsAndroid DeveloperBecome an iOS DeveloperBusiness AnalystComputer VisionData AnalystData FoundationsDesign Sprint FoundationsFront-End Web DeveloperFull Stack Web DeveloperGoogle AdWordsIntro to ProgrammingMachine Learning EngineerNatural Language ProcessingReactOnly At UdacityArtificial IntelligenceDeep LearningDigital MarketingFlying Cars &amp; Autonomous FlightIntro to Self-Driving CarLearn AR KitLearn Unreal VRRobotics Software EngineerSelf-Driving CarVR DeveloperSupportContact UsHelp and FAQService StatusResourcesFree Course CatalogCareer Resource CenterHiring PartnersStudent SuccessFor BusinessUdacity for BusinessCorporate TrainingHire GraduatesAbout UdacityAboutBlogJobsMobile© 2011–2018 Udacity, Inc.Legal &amp; PrivacySite MapEuropeBrasilChinaGermanyIndiaUnited States"Nanodegree" is a registered trademark of Udacity. © 2011–2018 Udacity, Inc.Udacity is not an accredited university and we don't confer traditional degrees. Udacity Nanodegree programs represent collaborations with our industry partners who help us develop our content and who hire many of our program graduates. This website uses cookies to provide and improve our service as well customize your experience. By using this site, you agree to this use. Learn more{&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavLinks&a;locale=en-EU&q;:[{&q;href&q;:&q;/nanodegree&q;,&q;text&q;:&q;Nanodegrees&q;},{&q;href&q;:&q;/courses/all&q;,&q;text&q;:&q;Catalog&q;},{&q;href&q;:&q;https://www.udacity.com/business&q;,&q;text&q;:&q;For Business&q;},{&q;href&q;:&q;https://eu.udacity.com/blog/&q;,&q;text&q;:&q;Blog&q;}],&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthMobileLinks&a;locale=en-EU&q;:{&q;isAuth&q;:[{&q;text&q;:&q;My Classroom&q;,&q;href&q;:&q;https://classroom.udacity.com/&q;,&q;classes&q;:[&q;blue&q;]}],&q;isNotAuth&q;:[{&q;text&q;:&q;Sign In&q;,&q;href&q;:&q;https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;blue&q;]},{&q;text&q;:&q;Get Started&q;,&q;href&q;:&q;https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;turquoise&q;]}]},&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerSpecialUrlLinks&a;locale=en-EU&q;:[],&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthLinks&a;locale=en-EU&q;:{&q;isAuth&q;:[{&q;text&q;:&q;My Classroom&q;,&q;href&q;:&q;https://classroom.udacity.com/&q;,&q;classes&q;:[&q;button--primary&q;]}],&q;isNotAuth&q;:[{&q;text&q;:&q;Sign In&q;,&q;href&q;:&q;https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated&q;},{&q;text&q;:&q;Get Started&q;,&q;href&q;:&q;https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;button--turquoise&q;]}]},&q;/courses/all@CACHE_LOCALIZED_DATA-catalogFilters&a;locale=en-EU&q;:[{&q;section&q;:&q;Type&q;,&q;values&q;:[{&q;title&q;:&q;Nanodegree&q;,&q;propertyPath&q;:&q;slug&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;--nd&q;}},{&q;title&q;:&q;Free Courses&q;,&q;propertyPath&q;:&q;slug&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;notWithKey&q;:&q;-- ...

# %%
from bs4 import BeautifulSoup

# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
# Catalog | Udacityhtml[_ngcontent-c0]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c0], [_ngcontent-c0]:after, [_ngcontent-c0]:before{-webkit-box-sizing:inherit;box-sizing:inherit}a[_ngcontent-c0]{color:#9400d3}body[_ngcontent-c0]{color:#028bb1}[_nghost-c0]{display:block;position:relative}html[_ngcontent-c1]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c1], [_ngcontent-c1]:after, [_ngcontent-c1]:before{-webkit-box-sizing:inherit;box-sizing:inherit}.invisible[_ngcontent-c1]{visibility:hidden!important}.hide[_ngcontent-c1]{display:none!important}.show[_ngcontent-c1]{display:block!important}.sr-only[_ngcontent-c1]{height:1px;width:1px;overflow:hidden;position:absolute!important;clip:rect(1px,1px,1px,1px)}.hidden-xs-up[_ngcontent-c1]{display:none!important}@media (max-width:479px){.hidden-xs-down[_ngcontent-c1]{display:none!important}}@media (min-width:480px){.hidden-sm-up[_ngcontent-c1]{display:none!important}}@media (max-width:767px){.hidden-sm-down[_ngcontent-c1]{display:none!important}}@media (min-width:768px){.hidden-md-up[_ngcontent-c1]{display:none!important}}@media (max-width:991px){.hidden-md-down[_ngcontent-c1]{display:none!important}}@media (min-width:992px){.hidden-lg-up[_ngcontent-c1]{display:none!important}}@media (max-width:1179px){.hidden-lg-down[_ngcontent-c1]{display:none!important}}@media (min-width:1180px){.hidden-xl-up[_ngcontent-c1]{display:none!important}}.hidden-xl-down[_ngcontent-c1], .visible-print-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-block[_ngcontent-c1]{display:block!important}}.visible-print-inline[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline[_ngcontent-c1]{display:inline!important}}.visible-print-inline-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline-block[_ngcontent-c1]{display:inline-block!important}}@media print{.hidden-print[_ngcontent-c1]{display:none!important}}#contain-all[_ngcontent-c1]{width:100%;overflow:hidden;background:#fff;-webkit-backface-visibility:hidden;backface-visibility:hidden;-webkit-transform-style:preserve-3d}.outer_contain[_ngcontent-c1]{margin:0 auto;max-width:90rem}.contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto;padding-top:3rem;padding-bottom:3rem;padding-left:1.5rem;padding-right:1.5rem}.contain[_ngcontent-c1]:after{clear:both;content:"";display:table}@media screen and (min-width:48rem){.contain[_ngcontent-c1]{padding-top:6rem;padding-bottom:6rem}}@media screen and (min-width:73.75rem){.contain[_ngcontent-c1]{padding-left:0;padding-right:0}}.contain.no-padding[_ngcontent-c1]{padding:0}.contain.no-padding-top[_ngcontent-c1]{padding-top:0}.contain--none[_ngcontent-c1], .contain.no-padding-bottom[_ngcontent-c1]{padding-bottom:0}.contain--none[_ngcontent-c1]{padding-top:0;margin:0 auto}@media screen and (min-width:48rem){.contain--none[_ngcontent-c1]{padding-top:0;padding-bottom:0}}.contain--small[_ngcontent-c1]{padding-top:3rem;padding-bottom:3rem;margin:0 auto}@media screen and (min-width:48rem){.contain--small[_ngcontent-c1]{padding-top:4.5rem;padding-bottom:4.5rem}}.cards_contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto}.cards_contain[_ngcontent-c1]:after{clear:both;content:"";display:table}[_ngcontent-c1]:-webkit-full-screen-ancestor{-webkit-animation:none!important;animation:none!important;-webkit-animation-fill-mode:none!important;animation-fill-mode:none!important}[_ngcontent-c1]:target:before{content:"";display:inline-block;height:130px;margin:-130px 0 0}.header[_ngcontent-c1]{max-width:100%;margin-left:auto;margin-right:auto}.header[_ngcontent-c1]:after{clear:both;content:"";display:table}.header.header--clone[_ngcontent-c1]{width:100%;top:-1000px}.header.header--clone[_ngcontent-c1]   .header__navbar[_ngcontent-c1]{height:4.5rem}.header.header--stick[_ngcontent-c1]{top:0;background-color:#fff;z-index:8000;-webkit-box-shadow:0 1px 2px rgba(0,0,0,.1);box-shadow:0 1px 2px rgba(0,0, ...

# %%
# Find all course summaries
summaries = soup.find_all("div", class_="course-summary-card")
summaries[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-01693c759680> in <module>()
#       1 # Find all course summaries
#       2 summaries = soup.find_all("div", class_="course-summary-card")
# ----> 3 summaries[0]
#
# IndexError: list index out of range

# %%
# Extract title
summaries[0].select_one("h3 a").get_text().strip()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-28bb616a928a> in <module>()
#       1 # Extract title
# ----> 2 summaries[0].select_one("h3 a").get_text().strip()
#
# IndexError: list index out of range

# %%
# Extract description
summaries[0].select_one("div[data-course-short-summary]").get_text().strip()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-d5c10c9d187d> in <module>()
#       1 # Extract description
# ----> 2 summaries[0].select_one("div[data-course-short-summary]").get_text().strip()
#
# IndexError: list index out of range

# %%
# Find all course summaries, extract title and description
courses = []
summaries = soup.find_all("div", class_="course-summary-card")
for summary in summaries:
    title = summary.select_one("h3 a").get_text().strip()
    description = summary.select_one("div[data-course-short-summary]").get_text().strip()
    courses.append((title, description))

print(len(courses), "course summaries found. Sample:")
print(courses[0][0])
print(courses[0][1])
# Out:
# 0 course summaries found. Sample:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-eb8b0b1749f3> in <module>()
#       8
#       9 print(len(courses), "course summaries found. Sample:")
# ---> 10 print(courses[0][0])
#      11 print(courses[0][1])
#
# IndexError: list index out of range

# %% [markdown]
# ## Normalization

# %% [markdown]
# ### Case Normalization

# %%
# Sample text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"
print(text)
# Out:
# The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?

# %%
# Convert to lowercase
text = text.lower() 
print(text)
# Out:
# the first time you see the second renaissance it may look boring. look at it at least twice and definitely watch part 2. it will change your view of the matrix. are the human people the ones who started the war ? is ai a bad thing ?

# %% [markdown]
# ### Punctuation Removal

# %%
import re

# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]", " ", text) 
print(text)
# Out:
# the first time you see the second renaissance it may look boring  look at it at least twice and definitely watch part 2  it will change your view of the matrix  are the human people the ones who started the war   is ai a bad thing

# %% [markdown]
# ## Tokenization

# %%
# Split text into tokens (words)
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %% [markdown]
# ### NLTK: Natural Language ToolKit

# %%
# Another sample text
text = "Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers."
print(text)
# Out:
# Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers.

# %%
from nltk.tokenize import word_tokenize

# Split text into words using NLTK
words = word_tokenize(text)
print(words)
# Out:
# ['Dr.', 'Smith', 'graduated', 'from', 'the', 'University', 'of', 'Washington', '.', 'He', 'later', 'started', 'an', 'analytics', 'firm', 'called', 'Lux', ',', 'which', 'catered', 'to', 'enterprise', 'customers', '.']

# %%
from nltk.tokenize import sent_tokenize

# Split text into sentences
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Dr. Smith graduated from the University of Washington.', 'He later started an analytics firm called Lux, which catered to enterprise customers.']

# %%
# List stop words
from nltk.corpus import stopwords
print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Reset text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"

# Normalize it
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# Tokenize it
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %%
# Remove stop words
words = [w for w in words if w not in stopwords.words("english")]
print(words)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'ones', 'started', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ## Part-of-Speech Tagging

# %%
from nltk import pos_tag

# Tag parts of speech (PoS)
sentence = word_tokenize("I always lie down to tell a lie.")
pos_tag(sentence)
# Out:
# [('I', 'PRP'),
#  ('always', 'RB'),
#  ('lie', 'VBP'),
#  ('down', 'RP'),
#  ('to', 'TO'),
#  ('tell', 'VB'),
#  ('a', 'DT'),
#  ('lie', 'NN'),
#  ('.', '.')]

# %% [markdown]
# ### Sentence Parsing

# %%
import nltk

# Define a custom grammar
my_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")
parser = nltk.ChartParser(my_grammar)

# Parse a sentence
sentence = word_tokenize("I shot an elephant in my pajamas")
for tree in parser.parse(sentence):
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %%
import IPython  # for displaying parse trees inline

# Visualize parse trees
for tree in parser.parse(sentence):
    IPython.display.display(tree)  # instead of tree.draw()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# c:\miniconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# c:\miniconda3\lib\site-packages\nltk\tree.py in _repr_png_(self)
#     728             _canvas_frame.print_to_file(in_path)
#     729             _canvas_frame.destroy_widget(widget)
# --> 730             subprocess.call([find_binary('gs', binary_names=['gswin32c.exe', 'gswin64c.exe'], env_vars=['PATH'], verbose=False)] +
#     731                             '-q -dEPSCrop -sDEVICE=png16m -r90 -dTextAlphaBits=4 -dGraphicsAlphaBits=4 -dSAFER -dBATCH -dNOPAUSE -sOutputFile={0:} {1:}'
#     732                             .format(out_path, in_path).split())
#
# c:\miniconda3\lib\site-packages\nltk\__init__.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     602                 binary_names=None, url=None, verbose=False):
#     603     return next(find_binary_iter(name, path_to_bin, env_vars, searchpath,
# --> 604                                  binary_names, url, verbose))
#     605
#     606 def find_jar_iter(name_pattern, path_to_jar=None, env_vars=(),
#
# c:\miniconda3\lib\site-packages\nltk\__init__.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     596     """
#     597     for file in  find_file_iter(path_to_bin or name, env_vars, searchpath, binary_names,
# --> 598                      url, verbose):
#     599         yield file
#     600
#
# c:\miniconda3\lib\site-packages\nltk\__init__.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     567                         (filename, url))
#     568         div = '='*75
# --> 569         raise LookupError('\n\n%s\n%s\n%s' % (div, msg, div))
#     570
#     571
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
# Tree('S', [Tree('NP', ['I']), Tree('VP', [Tree('VP', [Tree('V', ['shot']), Tree('NP', [Tree('Det', ['an']), Tree('N', ['elephant'])])]), Tree('PP', [Tree('P', ['in']), Tree('NP', [Tree('Det', ['my']), Tree('N', ['pajamas'])])])])])
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# c:\miniconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# c:\miniconda3\lib\site-packages\nltk\tree.py in _repr_png_(self)
#     728             _canvas_frame.print_to_file(in_path)
#     729             _canvas_frame.destroy_widget(widget)
# --> 730             subprocess.call([find_binary('gs', binary_names=['gswin32c.exe', 'gswin64c.exe'], env_vars=['PATH'], verbose=False)] +
#     731                             '-q -dEPSCrop -sDEVICE=png16m -r90 -dTextAlphaBits=4 -dGraphicsAlphaBits=4 -dSAFER -dBATCH -dNOPAUSE -sOutputFile={0:} {1:}'
#     732                             .format(out_path, in_path).split())
#
# c:\miniconda3\lib\site-packages\nltk\__init__.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     602                 binary_names=None, url=None, verbose=False):
#     603     return next(find_binary_iter(name, path_to_bin, env_vars, searchpath,
# --> 604                                  binary_names, url, verbose))
#     605
#     606 def find_jar_iter(name_pattern, path_to_jar=None, env_vars=(),
#
# c:\miniconda3\lib\site-packages\nltk\__init__.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     596     """
#     597     for file in  find_file_iter(path_to_bin or name, env_vars, searchpath, binary_names,
# --> 598                      url, verbose):
#     599         yield file
#     600
#
# c:\miniconda3\lib\site-packages\nltk\__init__.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     567                         (filename, url))
#     568         div = '='*75
# --> 569         raise LookupError('\n\n%s\n%s\n%s' % (div, msg, div))
#     570
#     571
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
# Tree('S', [Tree('NP', ['I']), Tree('VP', [Tree('V', ['shot']), Tree('NP', [Tree('Det', ['an']), Tree('N', ['elephant']), Tree('PP', [Tree('P', ['in']), Tree('NP', [Tree('Det', ['my']), Tree('N', ['pajamas'])])])])])])

# %%
from nltk import pos_tag, ne_chunk
from nltk.tokenize import word_tokenize

# Recognize named entities in a tagged sentence
tree = ne_chunk(pos_tag(word_tokenize("Antonio joined Udacity Inc. in California.")))
IPython.display.display(tree)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# c:\miniconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# c:\miniconda3\lib\site-packages\nltk\tree.py in _repr_png_(self)
#     728             _canvas_frame.print_to_file(in_path)
#     729             _canvas_frame.destroy_widget(widget)
# --> 730             subprocess.call([find_binary('gs', binary_names=['gswin32c.exe', 'gswin64c.exe'], env_vars=['PATH'], verbose=False)] +
#     731                             '-q -dEPSCrop -sDEVICE=png16m -r90 -dTextAlphaBits=4 -dGraphicsAlphaBits=4 -dSAFER -dBATCH -dNOPAUSE -sOutputFile={0:} {1:}'
#     732                             .format(out_path, in_path).split())
#
# c:\miniconda3\lib\site-packages\nltk\__init__.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     602                 binary_names=None, url=None, verbose=False):
#     603     return next(find_binary_iter(name, path_to_bin, env_vars, searchpath,
# --> 604                                  binary_names, url, verbose))
#     605
#     606 def find_jar_iter(name_pattern, path_to_jar=None, env_vars=(),
#
# c:\miniconda3\lib\site-packages\nltk\__init__.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     596     """
#     597     for file in  find_file_iter(path_to_bin or name, env_vars, searchpath, binary_names,
# --> 598                      url, verbose):
#     599         yield file
#     600
#
# c:\miniconda3\lib\site-packages\nltk\__init__.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     567                         (filename, url))
#     568         div = '='*75
# --> 569         raise LookupError('\n\n%s\n%s\n%s' % (div, msg, div))
#     570
#     571
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
# Tree('S', [Tree('PERSON', [('Antonio', 'NNP')]), ('joined', 'VBD'), Tree('ORGANIZATION', [('Udacity', 'NNP'), ('Inc.', 'NNP')]), ('in', 'IN'), Tree('GPE', [('California', 'NNP')]), ('.', '.')])

# %% [markdown]
# ## Stemming & Lemmatization
#
# ### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaiss', 'may', 'look', 'bore', 'look', 'least', 'twice', 'definit', 'watch', 'part', '2', 'chang', 'view', 'matrix', 'human', 'peopl', 'one', 'start', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'one', 'started', 'war', 'ai', 'bad', 'thing']

# %%
# Lemmatize verbs by specifying pos
lemmed = [WordNetLemmatizer().lemmatize(w, pos='v') for w in lemmed]
print(lemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'bore', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'one', 'start', 'war', 'ai', 'bad', 'thing']
