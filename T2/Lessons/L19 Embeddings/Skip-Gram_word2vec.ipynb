# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# c:\miniconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:05, 476kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

t = 1e-5
word_counts = Counter(int_words)
total_words = len(words)

freqs = {word: count/total_words for word, count in word_counts.items()}
p = {word: 1 - np.sqrt(t/freqs[word]) for word in word_counts}

train_words = [word for word in int_words if p[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R

    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
#will help if you get stuck.

n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From c:\miniconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:1346: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6627 0.0263 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6328 0.0230 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5243 0.0234 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5876 0.0231 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5140 0.0229 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5738 0.0228 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5820 0.0231 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5576 0.0236 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4529 0.0234 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4513 0.0233 sec/batch
# Nearest to which: torontonians, pursuers, calculated, vander, flash, madly, tyr, jef,
# Nearest to all: trackball, start, enclaves, uris, anakkale, autoerotic, cataract, glibc,
# Nearest to they: renga, corned, textures, shepherd, wallowing, undertaking, luxemburg, radius,
# Nearest to into: suggestions, mafiosi, mbps, actuated, adjoint, greta, tyramine, postseason,
# Nearest to world: oita, sedans, dynastic, thorny, morel, crashed, transmission, esquire,
# Nearest to nine: colander, sorceress, minotaur, admirative, glibc, reproductions, made, dustin,
# Nearest to an: nodens, cardiology, pidgin, neared, median, lukoff, division, tapaj,
# Nearest to are: exiles, wrestled, argand, empowering, szdsz, win, costner, clay,
# Nearest to nobel: consent, fa, shui, bessie, latgale, ert, antagonism, malays,
# Nearest to smith: dreidel, cranberry, sociopolitical, raises, serie, slowness, meatballwiki, passers,
# Nearest to proposed: pali, milla, bcc, digest, godley, salamanca, jul, consecrated,
# Nearest to stage: rapier, fairies, seto, herself, psi, logged, timelines, cord,
# Nearest to egypt: safari, wassily, ernie, crossbar, beds, enver, shorthair, minimised,
# Nearest to dr: locusts, rectifier, brocklin, tanto, enough, gangetic, ly, sfr,
# Nearest to channel: ponder, wholly, mato, golf, honeys, reinhardt, diffuse, jimmy,
# Nearest to active: makes, platonic, isc, servitude, fat, idiomatically, women, counterinsurgency,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4888 0.0244 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3799 0.0230 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3231 0.0234 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2664 0.0232 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1712 0.0230 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1556 0.0231 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1120 0.0229 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0808 0.0229 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9992 0.0230 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9954 0.0229 sec/batch
# Nearest to which: calculated, disappeared, unnatural, torontonians, flash, based, alone, defends,
# Nearest to all: start, constructed, trackball, glibc, laugh, enclaves, conceptually, banners,
# Nearest to they: textures, collection, expressed, corned, radius, notably, renga, moist,
# Nearest to into: suggestions, mafiosi, conductive, audiences, decade, not, crossovers, colonies,
# Nearest to world: sedans, controversy, oita, minimum, improve, crashed, looked, institute,
# Nearest to nine: made, declared, wednesday, ago, reproductions, forces, sorceress, glibc,
# Nearest to an: division, median, pidgin, would, upon, nodens, model, run,
# Nearest to are: exiles, wrestled, argand, empowering, win, river, controversial, clay,
# Nearest to nobel: consent, fa, shui, latgale, ert, malays, chinon, scifan,
# Nearest to smith: cranberry, dreidel, majorities, meatballwiki, slowness, requires, raises, possible,
# Nearest to proposed: scientist, digest, pali, empirical, bcc, meaningless, veto, jul,
# Nearest to stage: fairies, rapier, herself, timelines, printer, psi, formal, seto,
# Nearest to egypt: safari, wassily, ernie, crossbar, beds, enver, shorthair, putnam,
# Nearest to dr: enough, locusts, tanto, transforms, norm, rectifier, brocklin, sfr,
# Nearest to channel: wholly, ponder, golf, jimmy, board, unchanged, settlements, chains,
# Nearest to active: makes, fat, platonic, isc, women, servitude, missionaries, mendicant,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9373 0.0241 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8995 0.0234 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9062 0.0233 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8520 0.0232 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8053 0.0229 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8228 0.0232 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7916 0.0231 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7749 0.0230 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7775 0.0231 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7844 0.0230 sec/batch
# Nearest to which: calculated, precedent, unnatural, flash, torontonians, disappeared, madly, pursuers,
# Nearest to all: start, trackball, glibc, cataract, conner, enclaves, uris, unprofitable,
# Nearest to they: textures, extends, renga, expressed, shepherd, undertaking, corned, illness,
# Nearest to into: suggestions, alphabet, decade, mafiosi, crossovers, conductive, mbps, rudolf,
# Nearest to world: sedans, crashed, preston, oita, dynastic, transmission, looked, kobe,
# Nearest to nine: three, wednesday, declared, made, six, ago, clever, sorceress,
# Nearest to an: pidgin, median, division, nodens, borrowing, model, cardiology, styling,
# Nearest to are: wrestled, exiles, szdsz, argand, clay, empowering, linking, blue,
# Nearest to nobel: consent, fa, shui, ert, gpl, struggles, sounds, omits,
# Nearest to smith: slowness, raises, cranberry, majorities, dreidel, meatballwiki, downloading, restore,
# Nearest to proposed: digest, consecrated, theoretically, pali, meaningless, jul, scientist, veto,
# Nearest to stage: rapier, fairies, herself, timelines, psi, printer, logged, cord,
# Nearest to egypt: safari, ernie, beds, crossbar, wassily, putnam, physician, arthurian,
# Nearest to dr: locusts, enough, transforms, tanto, norm, ly, infallibility, smarteiffel,
# Nearest to channel: wholly, golf, jimmy, ponder, board, unchanged, settlements, focusing,
# Nearest to active: makes, fat, platonic, women, servitude, isc, missionaries, nelson,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7700 0.0239 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7651 0.0230 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7381 0.0232 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6999 0.0234 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7406 0.0238 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7032 0.0237 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7246 0.0234 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7203 0.0231 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6996 0.0230 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6685 0.0232 sec/batch
# Nearest to which: precedent, calculated, unnatural, flash, torontonians, madly, mundane, pursuers,
# Nearest to all: start, cataract, trackball, enclaves, conner, josip, zulu, uris,
# Nearest to they: textures, renga, blood, expressed, illness, corned, extends, undertaking,
# Nearest to into: suggestions, mbps, mafiosi, conductive, floats, actuated, alphabet, crossovers,
# Nearest to world: sedans, crashed, preston, esquire, kobe, dynastic, oita, morel,
# Nearest to nine: three, six, wednesday, george, five, dunbar, one, astor,
# Nearest to an: pidgin, division, cardiology, median, nodens, borrowing, model, guides,
# Nearest to are: wrestled, szdsz, stitching, argand, exiles, costner, linking, avril,
# Nearest to nobel: consent, fa, shui, cartoonist, chinon, latgale, ert, badlands,
# Nearest to smith: slowness, meatballwiki, serie, refering, cranberry, raises, vicksburg, majorities,
# Nearest to proposed: pali, theoretically, digest, consecrated, jul, bcc, veto, iucn,
# Nearest to stage: rapier, fairies, psi, herself, timelines, recombination, printer, seto,
# Nearest to egypt: beds, safari, ernie, wassily, crossbar, putnam, physician, enver,
# Nearest to dr: locusts, ly, tanto, norm, transforms, enough, infallibility, rectifier,
# Nearest to channel: wholly, golf, ponder, board, jimmy, suffices, settlements, unchanged,
# Nearest to active: fat, makes, platonic, isc, servitude, women, idiomatically, actuated,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6645 0.0251 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6686 0.0237 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6042 0.0229 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6354 0.0226 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6390 0.0230 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6323 0.0234 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5916 0.0175 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5616 0.0234 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4916 0.0235 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5000 0.0231 sec/batch
# Nearest to which: precedent, calculated, torontonians, peptidoglycan, madly, corrosive, mundane, flash,
# Nearest to all: start, cataract, trackball, conceptually, josip, conner, zulu, enclaves,
# Nearest to they: textures, blood, renga, illness, alpacas, expressed, undertaking, wallowing,
# Nearest to into: suggestions, mbps, mafiosi, actuated, conductive, crossovers, alphabet, chromatic,
# Nearest to world: sedans, crashed, preston, kobe, dynastic, esquire, institute, oita,
# Nearest to nine: three, six, five, writer, one, laureate, george, astor,
# Nearest to an: pidgin, guides, division, cardiology, styling, grind, model, eliminating,
# Nearest to are: szdsz, wrestled, costner, linking, stitching, clay, sets, mature,
# Nearest to nobel: cartoonist, singer, comedian, consent, fa, economist, shui, leopold,
# Nearest to smith: refering, slowness, serie, meatballwiki, vicksburg, dreidel, raises, dixie,
# Nearest to proposed: pali, theoretically, consecrated, iucn, bcc, jul, digest, empirical,
# Nearest to stage: rapier, fairies, psi, pull, timelines, recombination, herself, logged,
# Nearest to egypt: wassily, safari, beds, ernie, putnam, crossbar, enver, spades,
# Nearest to dr: locusts, ly, tanto, brocklin, rectifier, norm, smarteiffel, infallibility,
# Nearest to channel: wholly, golf, ponder, suffices, reinhardt, honeys, board, mato,
# Nearest to active: fat, makes, platonic, isc, servitude, actuated, women, idiomatically,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5121 0.0243 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4754 0.0234 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4580 0.0231 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5437 0.0231 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5038 0.0233 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4865 0.0234 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4454 0.0236 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3921 0.0230 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4181 0.0237 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4367 0.0232 sec/batch
# Nearest to which: calculated, torontonians, corrosive, flash, precedent, madly, peptidoglycan, pursuers,
# Nearest to all: cataract, start, trackball, conceptually, beauties, conner, unprofitable, breakbeats,
# Nearest to they: blood, textures, alpacas, renga, wallowing, expressed, illness, undertaking,
# Nearest to into: suggestions, mbps, conductive, actuated, crossovers, alphabet, chromatic, mafiosi,
# Nearest to world: crashed, kobe, sedans, broadcasts, affairs, oita, championships, institute,
# Nearest to nine: three, six, five, sorceress, medal, dunbar, astor, reproductions,
# Nearest to an: pidgin, eliminating, nodens, would, borrowing, cardiology, grind, sensory,
# Nearest to are: szdsz, wrestled, linking, shepherds, costner, sets, stitching, unprofessional,
# Nearest to nobel: cartoonist, singer, fa, comedian, biochemist, consent, leopold, chinon,
# Nearest to smith: serie, refering, meatballwiki, vicksburg, dreidel, dixie, sociopolitical, slowness,
# Nearest to proposed: pali, theoretically, iucn, bcc, consecrated, digest, veto, empirical,
# Nearest to stage: rapier, fairies, herself, recombination, pull, timelines, logged, printer,
# Nearest to egypt: wassily, putnam, safari, ernie, crossbar, enver, spades, empire,
# Nearest to dr: locusts, ly, tanto, brocklin, rectifier, infallibility, kapital, smarteiffel,
# Nearest to channel: wholly, golf, mato, ponder, board, suffices, focusing, honeys,
# Nearest to active: makes, isc, fat, idiomatically, servitude, actuated, platonic, counterinsurgency,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4173 0.0245 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4519 0.0233 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4200 0.0232 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4082 0.0239 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4137 0.0239 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4585 0.0235 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3702 0.0231 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3822 0.0232 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4003 0.0231 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3888 0.0241 sec/batch
# Nearest to which: torontonians, corrosive, pursuers, precedent, malfunction, calculated, flash, peptidoglycan,
# Nearest to all: trackball, cataract, start, conceptually, breakbeats, conner, constructed, josip,
# Nearest to they: blood, textures, alpacas, dewar, illness, dusting, wrath, undertaking,
# Nearest to into: suggestions, mbps, conductive, crossovers, alphabet, chromatic, actuated, mafiosi,
# Nearest to world: kobe, crashed, sedans, preston, championships, affairs, broadcasts, nearing,
# Nearest to nine: three, six, five, one, sorceress, medal, dunbar, reproductions,
# Nearest to an: pidgin, eliminating, guides, nodens, borrowing, would, neared, cardiology,
# Nearest to are: shepherds, stitching, szdsz, clay, linking, sets, essentialist, unprofessional,
# Nearest to nobel: cartoonist, fa, economist, leopold, biochemist, chinon, comedian, singer,
# Nearest to smith: serie, refering, dreidel, meatballwiki, vicksburg, slowness, dixie, sociopolitical,
# Nearest to proposed: pali, theoretically, iucn, empirical, bcc, improper, consecrated, veto,
# Nearest to stage: herself, fairies, rapier, smiling, logged, pull, requesting, dive,
# Nearest to egypt: wassily, empire, unorganized, cambodian, crossbar, putnam, enver, safari,
# Nearest to dr: locusts, ly, bodyguard, brocklin, kapital, smarteiffel, tanto, spamalot,
# Nearest to channel: golf, mato, wholly, honeys, ponder, board, reinhardt, canary,
# Nearest to active: idiomatically, servitude, isc, makes, fat, platonic, actuated, counterinsurgency,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3814 0.0249 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3998 0.0235 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3716 0.0233 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3620 0.0235 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4003 0.0234 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3627 0.0236 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3924 0.0229 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4025 0.0233 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3347 0.0236 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3232 0.0237 sec/batch
# Nearest to which: torontonians, peptidoglycan, explanations, balkanization, pursuers, calculated, precedent, malfunction,
# Nearest to all: cataract, trackball, start, educations, unprofitable, conceptually, conner, zulu,
# Nearest to they: blood, textures, alpacas, dusting, dewar, wrath, illness, gift,
# Nearest to into: suggestions, mbps, crossovers, conductive, chromatic, dermanland, nucleon, colonies,
# Nearest to world: kobe, affairs, nearing, broadcasts, crashed, sedans, championships, oita,
# Nearest to nine: three, six, five, one, sorceress, medal, radios, reproductions,
# Nearest to an: eliminating, borrowing, pidgin, guides, computation, grind, projectors, sensory,
# Nearest to are: szdsz, shepherds, sets, stitching, clay, essentialist, unprofessional, costner,
# Nearest to nobel: cartoonist, leopold, biochemist, fa, singer, economist, chinon, comedian,
# Nearest to smith: serie, refering, dreidel, vicksburg, premieres, archives, meatballwiki, slowness,
# Nearest to proposed: theoretically, veto, pali, empirical, iucn, bcc, consecrated, improper,
# Nearest to stage: smiling, fairies, rapier, herself, logged, pull, timelines, dive,
# Nearest to egypt: empire, unorganized, wassily, kfor, enver, beds, relations, putnam,
# Nearest to dr: locusts, bodyguard, smarteiffel, ly, tanto, brocklin, hippie, spamalot,
# Nearest to channel: honeys, golf, filesystem, ponder, board, easters, wholly, forcetoc,
# Nearest to active: idiomatically, makes, isc, servitude, fat, actuated, counterinsurgency, platonic,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3645 0.0237 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3049 0.0225 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3592 0.0232 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3693 0.0223 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3950 0.0224 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2769 0.0228 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3073 0.0221 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3215 0.0223 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2456 0.0224 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3096 0.0226 sec/batch
# Nearest to which: torontonians, subscribe, balkanization, housman, pursuers, malfunction, precedent, sejong,
# Nearest to all: cataract, start, trackball, educations, conner, unprofitable, merneptah, zulu,
# Nearest to they: textures, dusting, blood, wallowing, gift, alpacas, dewar, alleviation,
# Nearest to into: suggestions, mbps, crossovers, achaemenid, dermanland, figurehead, chromatic, knoxville,
# Nearest to world: kobe, broadcasts, championships, preston, affairs, nearing, crashed, sedans,
# Nearest to nine: three, one, five, six, radios, cricketer, astor, medal,
# Nearest to an: eliminating, borrowing, guides, grind, styling, projectors, computation, successors,
# Nearest to are: szdsz, shepherds, stitching, essentialist, clay, unprofessional, mature, sets,
# Nearest to nobel: cartoonist, economist, biochemist, leopold, geneticist, fa, astronomer, singer,
# Nearest to smith: serie, dreidel, refering, archives, slowness, meatballwiki, sar, vicksburg,
# Nearest to proposed: theoretically, veto, iucn, empirical, bcc, pali, consecrated, improper,
# Nearest to stage: herself, smiling, fairies, rapier, pull, dive, timelines, logged,
# Nearest to egypt: empire, unorganized, wassily, enver, kfor, beds, putnam, relations,
# Nearest to dr: locusts, bodyguard, brocklin, smarteiffel, ly, spamalot, rectifier, tanto,
# Nearest to channel: honeys, board, golf, railway, srs, filesystem, exceeding, ponder,
# Nearest to active: idiomatically, makes, servitude, actuated, fat, isc, counterinsurgency, minus,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3018 0.0234 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2819 0.0224 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3450 0.0100 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2485 0.0225 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2163 0.0223 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2305 0.0238 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2152 0.0229 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2188 0.0228 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2429 0.0235 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1944 0.0233 sec/batch
# Nearest to which: torontonians, housman, precedent, chestnut, sejong, balkanization, numerical, subscribe,
# Nearest to all: cataract, trackball, start, educations, josip, zulu, unprofitable, conner,
# Nearest to they: blood, dusting, textures, wallowing, up, dewar, alpacas, undertaking,
# Nearest to into: suggestions, mbps, achaemenid, conductive, crossovers, nucleon, actuated, chromatic,
# Nearest to world: kobe, broadcasts, championships, preston, nearing, crashed, sedans, toland,
# Nearest to nine: three, one, six, five, radios, cricketer, handbook, sorceress,
# Nearest to an: eliminating, projectors, neared, computation, grind, borrowing, would, styling,
# Nearest to are: szdsz, stitching, shepherds, clay, costner, mature, sets, prebiotic,
# Nearest to nobel: cartoonist, biochemist, geneticist, economist, leopold, prize, ert, fa,
# Nearest to smith: serie, dreidel, meatballwiki, refering, slowness, vicksburg, archives, spaten,
# Nearest to proposed: theoretically, veto, empirical, iucn, bcc, pali, meaningless, consecrated,
# Nearest to stage: dive, pull, rapier, fairies, harden, herself, smiling, logged,
# Nearest to egypt: enver, empire, wassily, unorganized, snowstorms, safavid, beds, kfor,
# Nearest to dr: locusts, brocklin, bodyguard, ly, smarteiffel, rectifier, spamalot, hippie,
# Nearest to channel: filesystem, honeys, board, ponder, forcetoc, golf, railway, mato,
# Nearest to active: idiomatically, actuated, makes, isc, servitude, fat, counterinsurgency, minus,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2519 0.0253 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2263 0.0236 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2092 0.0231 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1327 0.0233 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1921 0.0234 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1605 0.0233 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1512 0.0230 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1948 0.0235 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1962 0.0232 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1739 0.0235 sec/batch
# Nearest to which: torontonians, housman, chestnut, balkanization, numerical, precedent, malfunction, corrosive,
# Nearest to all: trackball, cataract, start, educations, consider, welded, conceptually, unprofitable,
# Nearest to they: blood, wallowing, dusting, gift, will, textures, alpacas, up,
# Nearest to into: suggestions, mbps, crossovers, conductive, dermanland, actuated, chromatic, adel,
# Nearest to world: kobe, broadcasts, nearing, championships, affairs, herbaceous, thracians, sedans,
# Nearest to nine: three, six, five, one, radios, handbook, cricketer, sorceress,
# Nearest to an: eliminating, projectors, computation, borrowing, cardiology, successors, would, guides,
# Nearest to are: szdsz, sets, shepherds, clay, stitching, prebiotic, mature, metric,
# Nearest to nobel: cartoonist, economist, biochemist, geneticist, leopold, prize, ert, dekker,
# Nearest to smith: dreidel, serie, meatballwiki, archives, spaten, sergey, slowness, revelations,
# Nearest to proposed: theoretically, empirical, bcc, iucn, scientist, meaningless, veto, pali,
# Nearest to stage: dive, pull, rapier, herself, harden, smiling, fairies, logged,
# Nearest to egypt: enver, wassily, empire, safavid, unorganized, kfor, beds, crossbar,
# Nearest to dr: locusts, bodyguard, brocklin, rectifier, ricketts, ly, smarteiffel, spamalot,
# Nearest to channel: honeys, pompidou, srs, jimmy, railway, board, filesystem, negotiated,
# Nearest to active: idiomatically, actuated, servitude, isc, makes, counterinsurgency, fat, ascents,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1895 0.0241 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2022 0.0230 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1975 0.0233 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1695 0.0235 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1848 0.0236 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2220 0.0235 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2161 0.0233 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1690 0.0231 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1193 0.0234 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1767 0.0239 sec/batch
# Nearest to which: torontonians, housman, precedent, numerical, monoclonal, recitations, balkanization, pbr,
# Nearest to all: cataract, trackball, start, consider, welded, educations, emphasising, zulu,
# Nearest to they: wallowing, gift, blood, will, wrath, dusting, alpacas, dewar,
# Nearest to into: suggestions, conductive, figurehead, mbps, crossovers, achaemenid, dermanland, chromatic,
# Nearest to world: kobe, championships, broadcasts, nearing, thracians, crashed, winchilsea, preston,
# Nearest to nine: three, six, one, five, est, radios, cricketer, runways,
# Nearest to an: eliminating, computation, papier, projectors, cardiology, neared, kindling, successors,
# Nearest to are: sets, szdsz, prebiotic, eigenfunctions, shepherds, clay, essentialist, mature,
# Nearest to nobel: cartoonist, biochemist, economist, geneticist, leopold, prize, dekker, chemist,
# Nearest to smith: dreidel, serie, archives, meatballwiki, spaten, slowness, version, sergey,
# Nearest to proposed: theoretically, empirical, iucn, scientist, pali, veto, bcc, jul,
# Nearest to stage: herself, smiling, pull, rapier, dive, fairies, harden, logged,
# Nearest to egypt: wassily, enver, safavid, beds, sudan, kfor, unorganized, empire,
# Nearest to dr: locusts, bodyguard, rectifier, brocklin, ricketts, smarteiffel, transforms, spamalot,
# Nearest to channel: honeys, pompidou, railway, jimmy, negotiated, srs, mato, filesystem,
# Nearest to active: idiomatically, servitude, counterinsurgency, isc, makes, actuated, fat, ascents,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1777 0.0252 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1796 0.0243 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1620 0.0238 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2074 0.0233 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1373 0.0231 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1336 0.0228 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1825 0.0232 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1777 0.0240 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1932 0.0231 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2012 0.0232 sec/batch
# Nearest to which: torontonians, precedent, housman, unnatural, sejong, recitations, balkanization, phrased,
# Nearest to all: start, cataract, trackball, welded, educations, consider, zulu, conner,
# Nearest to they: gift, will, wrath, up, alpacas, wallowing, invitation, revalued,
# Nearest to into: suggestions, figurehead, dermanland, crossovers, mbps, adel, achaemenid, conductive,
# Nearest to world: kobe, championships, thracians, broadcasts, nearing, winchilsea, preston, burma,
# Nearest to nine: three, one, five, six, cricketer, zero, four, eight,
# Nearest to an: eliminating, successors, papier, nodens, computation, guides, projectors, neared,
# Nearest to are: szdsz, sets, shepherds, essentialist, prebiotic, metric, costner, stitching,
# Nearest to nobel: economist, cartoonist, geneticist, prize, biochemist, chemist, astronomer, dekker,
# Nearest to smith: dreidel, archives, meatballwiki, slowness, version, spaten, dixie, sergey,
# Nearest to proposed: theoretically, empirical, veto, iucn, scientist, bcc, vladimir, criticized,
# Nearest to stage: herself, smiling, pull, rapier, fairies, logged, harden, confidential,
# Nearest to egypt: safavid, wassily, enver, beds, unorganized, kfor, sudan, empire,
# Nearest to dr: ricketts, locusts, bodyguard, brocklin, smarteiffel, rectifier, spamalot, artwork,
# Nearest to channel: srs, honeys, railway, filesystem, negotiated, pompidou, opencores, equilateral,
# Nearest to active: servitude, idiomatically, makes, counterinsurgency, isc, actuated, ascents, fat,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2327 0.0239 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1495 0.0236 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1003 0.0231 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1568 0.0235 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0224 0.0231 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1380 0.0230 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1411 0.0230 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1478 0.0232 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1760 0.0039 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1382 0.0230 sec/batch
# Nearest to which: torontonians, chestnut, pbr, housman, numerical, phrased, recitations, monoclonal,
# Nearest to all: start, trackball, welded, cataract, educations, conceptually, division, unprofitable,
# Nearest to they: wallowing, gift, textures, will, dusting, revalued, alpacas, up,
# Nearest to into: suggestions, mbps, conductive, figurehead, crossovers, achaemenid, dermanland, nucleon,
# Nearest to world: kobe, championships, broadcasts, thracians, usaid, nearing, herbaceous, crashed,
# Nearest to nine: three, one, six, five, zero, cricketer, four, eight,
# Nearest to an: eliminating, projectors, papier, guides, nodens, grind, lukoff, neared,
# Nearest to are: szdsz, metric, prebiotic, sets, essentialist, shepherds, mature, often,
# Nearest to nobel: prize, economist, cartoonist, biochemist, geneticist, chemist, astronomer, physicist,
# Nearest to smith: meatballwiki, dreidel, archives, slowness, spaten, serie, version, sergey,
# Nearest to proposed: theoretically, veto, scientist, empirical, iucn, bcc, jul, vladimir,
# Nearest to stage: herself, rapier, fairies, pull, smiling, logged, potentially, harden,
# Nearest to egypt: wassily, safavid, enver, beds, sudan, kfor, unorganized, snowstorms,
# Nearest to dr: ricketts, rectifier, locusts, bodyguard, brocklin, transforms, smarteiffel, tanto,
# Nearest to channel: srs, filesystem, broadcast, railway, honeys, pompidou, jimmy, equilateral,
# Nearest to active: idiomatically, servitude, makes, actuated, counterinsurgency, isc, jaffna, ascents,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0860 0.0243 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0951 0.0233 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0968 0.0230 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0523 0.0234 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0814 0.0240 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0564 0.0231 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0978 0.0232 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0928 0.0231 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0978 0.0230 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0473 0.0234 sec/batch
# Nearest to which: torontonians, chestnut, pbr, as, precedent, phrased, resume, recitations,
# Nearest to all: start, welded, trackball, consider, educations, cataract, division, emphasising,
# Nearest to they: gift, wallowing, will, blood, up, dewar, dusting, relocation,
# Nearest to into: suggestions, conductive, mbps, crossovers, figurehead, nucleon, could, mutagenesis,
# Nearest to world: kobe, championships, broadcasts, herbaceous, thracians, nearing, crashed, burma,
# Nearest to nine: three, six, five, one, est, zero, cricketer, four,
# Nearest to an: eliminating, projectors, neared, lukoff, guides, nodens, grind, papier,
# Nearest to are: be, prebiotic, metric, sets, szdsz, most, often, mature,
# Nearest to nobel: economist, prize, biochemist, geneticist, cartoonist, chemist, astronomer, dekker,
# Nearest to smith: meatballwiki, dreidel, slowness, archives, spaten, version, sergey, revelations,
# Nearest to proposed: theoretically, veto, iucn, empirical, scientist, jul, bcc, vladimir,
# Nearest to stage: pull, rapier, logged, dive, flew, fairies, potentially, harden,
# Nearest to egypt: safavid, egyptians, wassily, enver, hak, sudan, snowstorms, cairo,
# Nearest to dr: ricketts, rectifier, bodyguard, locusts, brocklin, tanto, transforms, smarteiffel,
# Nearest to channel: srs, filesystem, honeys, railway, pompidou, broadcast, jimmy, broadband,
# Nearest to active: idiomatically, makes, actuated, servitude, counterinsurgency, isc, ascents, andie,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0338 0.0242 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0311 0.0232 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0322 0.0229 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0833 0.0232 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0897 0.0231 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0278 0.0230 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0317 0.0227 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1336 0.0234 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0583 0.0236 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0417 0.0235 sec/batch
# Nearest to which: pbr, as, be, torontonians, that, chestnut, precedent, phrased,
# Nearest to all: consider, trackball, welded, start, educations, there, emphasising, cataract,
# Nearest to they: gift, wallowing, will, their, dusting, alleviation, relocation, yard,
# Nearest to into: suggestions, conductive, mbps, move, figurehead, nucleon, mutagenesis, outer,
# Nearest to world: kobe, championships, thracians, acrocorinth, broadcasts, nearing, crashed, herbaceous,
# Nearest to nine: three, five, six, one, zero, two, four, eight,
# Nearest to an: eliminating, computation, projectors, guides, lukoff, posttranslational, there, cardiology,
# Nearest to are: be, prebiotic, metric, most, sets, szdsz, often, all,
# Nearest to nobel: prize, economist, cartoonist, geneticist, biochemist, chemist, consent, ert,
# Nearest to smith: meatballwiki, dreidel, spaten, archives, version, sergey, slowness, revelations,
# Nearest to proposed: theoretically, iucn, scientist, empirical, veto, bcc, jul, vladimir,
# Nearest to stage: rapier, pull, fairies, herself, logged, dosomething, dive, flew,
# Nearest to egypt: sudan, egyptians, cairo, safavid, hak, wassily, kfor, beds,
# Nearest to dr: ricketts, rectifier, bodyguard, locusts, brocklin, smarteiffel, artwork, kipper,
# Nearest to channel: filesystem, honeys, railway, pompidou, srs, broadband, episode, jimmy,
# Nearest to active: idiomatically, servitude, counterinsurgency, actuated, isc, makes, ascents, lung,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0712 0.0248 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0979 0.0237 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0745 0.0230 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0855 0.0232 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0721 0.0235 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0539 0.0236 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0781 0.0230 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0864 0.0231 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0654 0.0232 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0631 0.0232 sec/batch
# Nearest to which: torontonians, phrased, as, pbr, precedent, chestnut, tonsure, recitations,
# Nearest to all: start, consider, trackball, welded, educations, emphasising, cataract, outtake,
# Nearest to they: gift, wallowing, relocation, will, dusting, overlord, up, belongings,
# Nearest to into: suggestions, figurehead, dermanland, mutagenesis, conductive, achaemenid, could, move,
# Nearest to world: championships, kobe, premiership, acrocorinth, nearing, thracians, looked, participants,
# Nearest to nine: three, one, six, five, zero, four, est, eight,
# Nearest to an: eliminating, neared, papier, cardiology, pave, nodens, grind, posttranslational,
# Nearest to are: be, prebiotic, sets, householder, szdsz, metric, often, most,
# Nearest to nobel: prize, economist, geneticist, cartoonist, biochemist, chemist, consent, laureate,
# Nearest to smith: meatballwiki, archives, dreidel, spaten, version, slowness, sergey, chosroes,
# Nearest to proposed: theoretically, iucn, empirical, vladimir, veto, scientist, reconcile, criticized,
# Nearest to stage: rapier, pull, logged, fairies, dosomething, herself, harden, smiling,
# Nearest to egypt: sudan, egyptians, cairo, kfor, safavid, suez, hak, relations,
# Nearest to dr: ricketts, rectifier, bodyguard, brocklin, smarteiffel, locusts, kipper, results,
# Nearest to channel: railway, filesystem, pompidou, honeys, srs, jimmy, episode, broadband,
# Nearest to active: servitude, idiomatically, counterinsurgency, isc, makes, actuated, ascents, uso,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0510 0.0241 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0141 0.0229 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0523 0.0234 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0576 0.0233 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0592 0.0234 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1275 0.0230 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1444 0.0229 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0344 0.0229 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0294 0.0232 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0647 0.0234 sec/batch
# Nearest to which: phrased, as, to, that, torontonians, pbr, syllabic, stipulate,
# Nearest to all: start, consider, welded, educations, trackball, emphasising, outtake, progressives,
# Nearest to they: gift, wallowing, whips, belongings, skipping, will, dusting, invitation,
# Nearest to into: suggestions, conductive, figurehead, move, dermanland, could, nucleon, mbps,
# Nearest to world: championships, kobe, premiership, nearing, burma, acrocorinth, participants, yuki,
# Nearest to nine: three, six, five, one, zero, four, two, eight,
# Nearest to an: eliminating, guides, papier, posttranslational, projectors, pave, cardiology, muso,
# Nearest to are: be, metric, prebiotic, szdsz, most, sets, householder, often,
# Nearest to nobel: prize, geneticist, economist, chemist, cartoonist, biochemist, consent, laureate,
# Nearest to smith: meatballwiki, dreidel, spaten, version, archives, chosroes, sergey, bonzos,
# Nearest to proposed: iucn, veto, scientist, empirical, theoretically, vladimir, jul, criticized,
# Nearest to stage: rapier, fairies, herself, logged, pull, dosomething, smiling, harden,
# Nearest to egypt: sudan, cairo, egyptians, wassily, hak, safavid, snowstorms, ariana,
# Nearest to dr: ricketts, bodyguard, brocklin, rectifier, smarteiffel, locusts, results, transforms,
# Nearest to channel: filesystem, honeys, railway, srs, pompidou, broadband, marketplace, equilateral,
# Nearest to active: idiomatically, servitude, counterinsurgency, makes, actuated, isc, andie, uso,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0094 0.0245 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0397 0.0228 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0461 0.0230 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0223 0.0229 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0906 0.0230 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0278 0.0203 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0081 0.0229 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9776 0.0231 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0148 0.0230 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9782 0.0233 sec/batch
# Nearest to which: as, phrased, torontonians, recitations, pbr, that, tonsure, trieste,
# Nearest to all: start, welded, consider, educations, trackball, division, djinni, there,
# Nearest to they: gift, wallowing, relocation, dusting, whips, yard, up, skipping,
# Nearest to into: suggestions, nucleon, conductive, figurehead, dermanland, mbps, mutagenesis, could,
# Nearest to world: championships, acrocorinth, premiership, nearing, kobe, yuki, participants, thracians,
# Nearest to nine: three, one, six, five, four, zero, two, eight,
# Nearest to an: projectors, eliminating, papier, grind, cardiology, posttranslational, muso, there,
# Nearest to are: be, prebiotic, householder, szdsz, metric, hechsher, sets, maior,
# Nearest to nobel: prize, economist, biochemist, cartoonist, geneticist, chemist, consent, erfurt,
# Nearest to smith: meatballwiki, dreidel, spaten, chosroes, version, bonzos, sergey, slowness,
# Nearest to proposed: iucn, empirical, veto, jul, theoretically, scientist, vladimir, bcc,
# Nearest to stage: rapier, dosomething, logged, pull, fairies, herself, flew, attitude,
# Nearest to egypt: cairo, sudan, ariana, snowstorms, hak, wassily, safavid, egyptians,
# Nearest to dr: ricketts, rectifier, smarteiffel, bodyguard, brocklin, transforms, hine, locusts,
# Nearest to channel: filesystem, honeys, broadcast, railway, marketplace, pompidou, broadband, episode,
# Nearest to active: idiomatically, servitude, counterinsurgency, actuated, andie, isc, missourians, riba,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9886 0.0247 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9587 0.0230 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0111 0.0228 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0221 0.0229 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0138 0.0230 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9898 0.0228 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9420 0.0231 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9819 0.0229 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9248 0.0229 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9369 0.0231 sec/batch
# Nearest to which: as, that, phrased, be, pbr, torontonians, to, recitations,
# Nearest to all: start, consider, welded, there, djinni, educations, unprofitable, are,
# Nearest to they: gift, relocation, yard, wallowing, their, will, whips, invitation,
# Nearest to into: suggestions, conductive, nucleon, mutagenesis, mbps, move, dermanland, portable,
# Nearest to world: championships, kobe, premiership, nearing, acrocorinth, third, yuki, participants,
# Nearest to nine: three, five, six, one, four, two, zero, eight,
# Nearest to an: eliminating, projectors, posttranslational, papier, honeybee, neared, guides, circumstances,
# Nearest to are: be, prebiotic, householder, metric, sets, most, all, couples,
# Nearest to nobel: prize, biochemist, cartoonist, economist, geneticist, consent, chemist, erfurt,
# Nearest to smith: meatballwiki, dreidel, version, chosroes, bonzos, spaten, slowness, refering,
# Nearest to proposed: iucn, theoretically, scientist, jul, veto, empirical, vladimir, bcc,
# Nearest to stage: rapier, logged, pull, dosomething, flew, attitude, herself, dive,
# Nearest to egypt: cairo, sudan, hak, ariana, wassily, relations, egyptians, safavid,
# Nearest to dr: ricketts, rectifier, smarteiffel, bodyguard, transforms, hine, brocklin, kipper,
# Nearest to channel: railway, honeys, filesystem, pompidou, episode, marketplace, standpoints, srs,
# Nearest to active: servitude, idiomatically, counterinsurgency, actuated, isc, ascents, loam, uso,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9982 0.0245 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0240 0.0229 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9493 0.0229 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0014 0.0231 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0248 0.0228 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9756 0.0231 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9824 0.0253 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9897 0.0248 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0077 0.0240 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0012 0.0236 sec/batch
# Nearest to which: that, as, pbr, to, torontonians, be, recitations, the,
# Nearest to all: consider, welded, start, there, emphasising, djinni, educations, over,
# Nearest to they: gift, relocation, wallowing, skipping, will, yard, whips, their,
# Nearest to into: conductive, nucleon, suggestions, figurehead, move, heaters, mutagenesis, dermanland,
# Nearest to world: premiership, championships, kobe, nearing, participants, exhibiting, acrocorinth, yuki,
# Nearest to nine: three, one, six, five, zero, eight, two, four,
# Nearest to an: eliminating, guides, projectors, muso, posttranslational, computation, pave, lukoff,
# Nearest to are: be, prebiotic, householder, metric, sets, often, most, all,
# Nearest to nobel: prize, biochemist, cartoonist, chemist, economist, geneticist, physicist, consent,
# Nearest to smith: meatballwiki, version, spaten, dreidel, chosroes, bonzos, revelations, lavoisier,
# Nearest to proposed: iucn, empirical, theoretically, jul, pali, kinesthetic, veto, scientist,
# Nearest to stage: rapier, logged, dosomething, pull, attitude, herself, fairies, flew,
# Nearest to egypt: cairo, hak, sudan, relations, suez, egyptians, kfor, announce,
# Nearest to dr: ricketts, rectifier, smarteiffel, bodyguard, brocklin, artwork, hine, kipper,
# Nearest to channel: honeys, railway, filesystem, pompidou, frankie, episode, easters, marketplace,
# Nearest to active: idiomatically, servitude, counterinsurgency, actuated, isc, loam, ascents, uso,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0048 0.0245 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9813 0.0230 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9912 0.0232 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0051 0.0232 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0165 0.0232 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0173 0.0233 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9604 0.0234 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9708 0.0232 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9567 0.0230 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0316 0.0235 sec/batch
# Nearest to which: as, that, to, the, torontonians, pbr, precedent, be,
# Nearest to all: start, welded, consider, emphasising, djinni, trackball, capybara, educations,
# Nearest to they: gift, their, wallowing, whips, will, skipping, were, relocation,
# Nearest to into: suggestions, figurehead, conductive, move, nucleon, dermanland, heaters, could,
# Nearest to world: premiership, championships, acrocorinth, thracians, nearing, kobe, burma, participants,
# Nearest to nine: three, one, five, six, zero, four, two, eight,
# Nearest to an: muso, eliminating, turboexpress, excludes, guides, borrowing, adopts, pave,
# Nearest to are: be, prebiotic, szdsz, heathland, householder, most, metric, differ,
# Nearest to nobel: prize, biochemist, chemist, cartoonist, geneticist, economist, physicist, lederman,
# Nearest to smith: meatballwiki, spaten, version, bonzos, dreidel, revelations, slowness, lavoisier,
# Nearest to proposed: iucn, empirical, veto, jul, theoretically, vladimir, kinesthetic, pali,
# Nearest to stage: rapier, dosomething, logged, pull, attitude, neurotoxicity, drusilla, anticonvulsants,
# Nearest to egypt: cairo, suez, sudan, relations, hak, putnam, announce, egyptians,
# Nearest to dr: ricketts, rectifier, smarteiffel, bodyguard, artwork, brocklin, hine, results,
# Nearest to channel: filesystem, honeys, railway, standpoints, easters, marketplace, pompidou, frankie,
# Nearest to active: servitude, idiomatically, counterinsurgency, actuated, loam, uso, convection, andie,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9951 0.0247 sec/batch
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7860 0.0230 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7844 0.0228 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8340 0.0231 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8960 0.0232 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8273 0.0232 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8690 0.0230 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9289 0.0235 sec/batch
# Nearest to which: the, as, of, its, in, that, a, to,
# Nearest to all: there, are, have, for, consider, of, remaining, to,
# Nearest to they: their, were, relocation, texans, whips, had, yard, to,
# Nearest to into: which, in, move, nucleon, an, through, the, of,
# Nearest to world: suppressors, olcott, participants, nearing, premiership, hungary, third, championships,
# Nearest to nine: one, three, five, six, four, eight, two, zero,
# Nearest to an: a, in, the, of, and, first, by, with,
# Nearest to are: is, be, most, or, living, all, there, only,
# Nearest to nobel: prize, awarded, geneticist, lederman, chemist, laureate, cartoonist, biochemist,
# Nearest to smith: revelations, scented, joseph, jr, bonzos, loretta, mormonism, version,
# Nearest to proposed: iucn, temporarily, superfluidity, by, postel, axiom, astonished, jul,
# Nearest to stage: rapier, dosomething, orbit, teslas, satyendra, attitude, cults, ramjet,
# Nearest to egypt: suez, putnam, cairo, jars, wassily, hilda, mina, hak,
# Nearest to dr: ricketts, bodyguard, kipper, sudanese, hydrate, kitagawa, hine, rectifier,
# Nearest to channel: ctv, channels, railway, saturdays, honeys, decency, filesystem, pbs,
# Nearest to active: claudette, initialism, ultraman, clutches, missionaries, every, jlp, substituted,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8337 0.0244 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8628 0.0239 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8790 0.0230 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8429 0.0232 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8356 0.0228 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8778 0.0229 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8467 0.0227 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8597 0.0238 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8863 0.0240 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8328 0.0233 sec/batch
# Nearest to which: the, as, of, in, its, that, into, first,
# Nearest to all: there, have, are, consider, for, of, survive, every,
# Nearest to they: their, were, relocation, texans, whips, had, will, jesse,
# Nearest to into: which, in, through, of, the, move, and, nucleon,
# Nearest to world: suppressors, premiership, champions, participants, champion, nearing, third, championships,
# Nearest to nine: one, three, six, five, eight, four, two, zero,
# Nearest to an: a, in, the, of, and, first, s, there,
# Nearest to are: is, most, be, living, or, all, there, these,
# Nearest to nobel: prize, awarded, geneticist, lederman, laureate, chemist, biochemist, cartoonist,
# Nearest to smith: revelations, scented, jr, loretta, bonzos, joseph, dreidel, raises,
# Nearest to proposed: iucn, by, temporarily, astonished, zayas, postel, superfluidity, axiom,
# Nearest to stage: dosomething, rapier, satyendra, teslas, orbit, cults, attitude, judgement,
# Nearest to egypt: suez, cairo, egyptian, jars, putnam, hilda, snowstorms, wassily,
# Nearest to dr: bodyguard, ricketts, kitagawa, sudanese, kipper, hydrate, hine, rectifier,
# Nearest to channel: ctv, channels, railway, saturdays, decency, honeys, pbs, filesystem,
# Nearest to active: initialism, clutches, claudette, every, ultraman, missionaries, ials, uso,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8438 0.0242 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8487 0.0232 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8402 0.0229 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8501 0.0231 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9002 0.0232 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8709 0.0230 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9482 0.0232 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8748 0.0232 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9177 0.0231 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8053 0.0238 sec/batch
# Nearest to which: the, as, of, that, its, in, to, into,
# Nearest to all: there, have, survive, consider, remaining, are, of, more,
# Nearest to they: their, were, relocation, whips, to, had, texans, bihari,
# Nearest to into: which, in, through, move, the, and, its, an,
# Nearest to world: suppressors, participants, premiership, nearing, olcott, champions, third, many,
# Nearest to nine: one, three, five, six, four, two, eight, zero,
# Nearest to an: a, in, of, the, and, s, first, by,
# Nearest to are: most, is, living, or, be, there, only, these,
# Nearest to nobel: prize, awarded, laureate, geneticist, chemist, biochemist, lederman, physicist,
# Nearest to smith: revelations, jr, scented, loretta, joseph, dreidel, bonzos, mormonism,
# Nearest to proposed: temporarily, iucn, by, astonished, postel, invocation, superfluidity, axiom,
# Nearest to stage: rapier, dosomething, teslas, satyendra, orbit, cults, eastwood, tempestuous,
# Nearest to egypt: suez, cairo, egyptian, hilda, mina, putnam, wassily, jars,
# Nearest to dr: bodyguard, ricketts, kitagawa, sudanese, kipper, rectifier, hydrate, sihanouk,
# Nearest to channel: ctv, channels, filesystem, saturdays, subscriptions, railway, decency, honeys,
# Nearest to active: claudette, initialism, clutches, ultraman, uso, ials, every, jlp,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8208 0.0244 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8598 0.0231 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7795 0.0229 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8679 0.0237 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8321 0.0230 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8436 0.0232 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9319 0.0112 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8270 0.0231 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8230 0.0228 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8294 0.0231 sec/batch
# Nearest to which: the, as, its, of, in, into, that, known,
# Nearest to all: there, have, are, survive, to, before, remaining, for,
# Nearest to they: their, were, relocation, texans, to, whips, bihari, odontoceti,
# Nearest to into: which, in, through, the, and, an, move, nucleon,
# Nearest to world: suppressors, olcott, participants, nearing, champion, premiership, champions, open,
# Nearest to nine: one, three, five, six, eight, four, two, zero,
# Nearest to an: a, in, the, of, first, s, is, and,
# Nearest to are: living, most, is, be, there, or, some, only,
# Nearest to nobel: prize, laureate, chemist, awarded, biochemist, lederman, geneticist, cartoonist,
# Nearest to smith: revelations, jr, scented, joseph, loretta, mormonism, dreidel, bonzos,
# Nearest to proposed: temporarily, iucn, astonished, postel, by, axiom, jul, invocation,
# Nearest to stage: dosomething, satyendra, teslas, orbit, rapier, mertens, judgement, ramjet,
# Nearest to egypt: suez, egyptian, cairo, jars, hilda, mina, snowstorms, putnam,
# Nearest to dr: ricketts, bodyguard, sudanese, kitagawa, rectifier, irredentist, kipper, hydrate,
# Nearest to channel: ctv, channels, subscriptions, saturdays, filesystem, decency, honeys, railway,
# Nearest to active: clutches, initialism, claudette, missionaries, ultraman, every, l, uso,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8422 0.0242 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8196 0.0234 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8294 0.0231 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7872 0.0230 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8587 0.0235 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8410 0.0235 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8642 0.0231 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7730 0.0237 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8002 0.0233 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8332 0.0233 sec/batch
# Nearest to which: the, as, of, that, in, its, a, into,
# Nearest to all: there, of, have, to, for, are, a, that,
# Nearest to they: their, were, relocation, texans, to, had, jesse, bihari,
# Nearest to into: which, in, the, and, through, move, an, of,
# Nearest to world: suppressors, olcott, third, participants, nearing, many, yuki, premiership,
# Nearest to nine: one, three, six, five, eight, four, two, zero,
# Nearest to an: a, in, of, the, and, s, which, with,
# Nearest to are: is, most, be, living, or, there, more, all,
# Nearest to nobel: prize, laureate, awarded, biochemist, chemist, lederman, geneticist, cartoonist,
# Nearest to smith: revelations, jr, joseph, scented, mormonism, loretta, dreidel, rigdon,
# Nearest to proposed: iucn, temporarily, by, astonished, postel, superfluidity, jul, zayas,
# Nearest to stage: dosomething, orbit, teslas, rapier, satyendra, ramjet, mertens, eastwood,
# Nearest to egypt: suez, cairo, jars, egyptian, putnam, hilda, mina, occasion,
# Nearest to dr: bodyguard, ricketts, sudanese, kitagawa, kipper, rectifier, irredentist, hydrate,
# Nearest to channel: ctv, channels, saturdays, subscriptions, decency, pbs, filesystem, emmitt,
# Nearest to active: initialism, claudette, clutches, ultraman, antiaircraft, missionaries, every, jlp,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7561 0.0241 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8101 0.0234 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8487 0.0234 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8602 0.0232 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8088 0.0229 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8949 0.0230 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8411 0.0234 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8362 0.0232 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8069 0.0232 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8455 0.0233 sec/batch
# Nearest to which: the, as, that, of, its, in, a, into,
# Nearest to all: there, have, are, for, of, consider, to, more,
# Nearest to they: their, were, relocation, texans, to, had, bihari, jesse,
# Nearest to into: which, in, through, the, nucleon, and, move, an,
# Nearest to world: olcott, suppressors, third, victory, champions, participants, premiership, nearing,
# Nearest to nine: one, three, five, six, two, eight, four, zero,
# Nearest to an: in, a, of, the, and, first, by, as,
# Nearest to are: living, be, or, most, is, only, there, all,
# Nearest to nobel: prize, laureate, awarded, chemist, lederman, biochemist, physicist, geneticist,
# Nearest to smith: revelations, jr, joseph, scented, loretta, raises, dreidel, mormonism,
# Nearest to proposed: iucn, temporarily, superfluidity, zayas, astonished, by, postel, hotbed,
# Nearest to stage: dosomething, orbit, satyendra, rapier, mertens, teslas, judgement, wasserman,
# Nearest to egypt: suez, egyptian, cairo, hilda, mina, putnam, jars, relations,
# Nearest to dr: bodyguard, ricketts, sudanese, kitagawa, hydrate, irredentist, rectifier, hine,
# Nearest to channel: ctv, channels, subscriptions, decency, saturdays, emmitt, filesystem, pbs,
# Nearest to active: initialism, claudette, clutches, ultraman, every, antiaircraft, elect, l,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8801 0.0242 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8081 0.0232 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7936 0.0230 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8465 0.0232 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8683 0.0232 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8317 0.0232 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8364 0.0229 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8546 0.0229 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8182 0.0236 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8076 0.0235 sec/batch
# Nearest to which: the, as, of, its, that, in, first, a,
# Nearest to all: have, there, survive, remaining, every, to, for, more,
# Nearest to they: their, were, relocation, to, texans, all, had, jesse,
# Nearest to into: which, in, and, through, move, the, nucleon, its,
# Nearest to world: olcott, suppressors, participants, champions, footballers, third, hungary, premiership,
# Nearest to nine: one, three, five, six, four, eight, two, zero,
# Nearest to an: a, in, of, the, and, first, is, as,
# Nearest to are: most, is, living, be, or, there, only, have,
# Nearest to nobel: prize, laureate, awarded, chemist, biochemist, lederman, geneticist, physicist,
# Nearest to smith: revelations, scented, jr, loretta, dreidel, mormonism, joseph, bonzos,
# Nearest to proposed: temporarily, by, iucn, astonished, invocation, hotbed, zayas, superfluidity,
# Nearest to stage: dosomething, satyendra, rapier, milah, teslas, mertens, judgement, orbit,
# Nearest to egypt: suez, egyptian, cairo, putnam, jars, mina, hilda, mesopotamia,
# Nearest to dr: ricketts, bodyguard, kitagawa, sudanese, kipper, rectifier, hydrate, irredentist,
# Nearest to channel: ctv, channels, subscriptions, filesystem, saturdays, decency, pbs, honeys,
# Nearest to active: clutches, initialism, claudette, ultraman, every, antiaircraft, l, ials,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8707 0.0249 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8197 0.0235 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9268 0.0234 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9131 0.0231 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9006 0.0237 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8592 0.0231 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8051 0.0233 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8164 0.0232 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7488 0.0231 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8614 0.0233 sec/batch
# Nearest to which: the, as, its, that, a, of, in, to,
# Nearest to all: there, have, more, consider, of, for, every, not,
# Nearest to they: their, were, to, relocation, whips, texans, bihari, had,
# Nearest to into: which, in, through, and, the, move, sulu, nucleon,
# Nearest to world: olcott, suppressors, champions, open, champion, hungary, footballers, participants,
# Nearest to nine: one, three, five, eight, six, four, zero, two,
# Nearest to an: a, in, of, the, and, as, s, is,
# Nearest to are: most, living, or, is, be, there, only, of,
# Nearest to nobel: prize, laureate, awarded, chemist, lederman, geneticist, biochemist, physicist,
# Nearest to smith: scented, revelations, jr, joseph, loretta, dreidel, mormonism, chosroes,
# Nearest to proposed: temporarily, astonished, iucn, invocation, zayas, by, hotbed, postel,
# Nearest to stage: dosomething, satyendra, mertens, rapier, orbit, judgement, wasserman, attitude,
# Nearest to egypt: egyptian, suez, cairo, mina, hilda, jars, putnam, wassily,
# Nearest to dr: ricketts, bodyguard, sudanese, cambodian, kitagawa, bonner, sihanouk, irredentist,
# Nearest to channel: channels, ctv, decency, filesystem, subscriptions, saturdays, emmitt, pbs,
# Nearest to active: claudette, l, initialism, ultraman, clutches, every, antiaircraft, ials,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8245 0.0245 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8239 0.0228 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
